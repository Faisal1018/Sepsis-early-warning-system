# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd

df = pd.read_csv("../data/Dataset.csv")

print(df.shape)
# Out:
# (546123, 44)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 546123 entries, 0 to 546122
# Data columns (total 44 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        546123 non-null  int64
#  1   Hour              546123 non-null  int64
#  2   HR                504000 non-null  float64
#  3   O2Sat             480319 non-null  float64
#  4   Temp              184511 non-null  float64
#  5   SBP               462920 non-null  float64
#  6   MAP               490527 non-null  float64
#  7   DBP               284671 non-null  float64
#  8   Resp              492675 non-null  float64
#  9   EtCO2             0 non-null       float64
#  10  BaseExcess        56478 non-null   float64
#  11  HCO3              43875 non-null   float64
#  12  FiO2              76575 non-null   float64
#  13  pH                62185 non-null   float64
#  14  PaCO2             47562 non-null   float64
#  15  SaO2              26680 non-null   float64
#  16  AST               8179 non-null    float64
#  17  BUN               44450 non-null   float64
#  18  Alkalinephos      7950 non-null    float64
#  19  Calcium           27186 non-null   float64
#  20  Chloride          45308 non-null   float64
#  21  Creatinine        36212 non-null   float64
#  22  Bilirubin_direct  818 non-null     float64
#  23  Glucose           66308 non-null   float64
#  24  Lactate           18683 non-null   float64
#  25  Magnesium         42391 non-null   float64
#  26  Phosphate         27606 non-null   float64
#  27  Potassium         59009 non-null   float64
#  28  Bilirubin_total   6718 non-null    float64
#  29  TroponinI         688 non-null     float64
#  30  Hct               64279 non-null   float64
#  31  Hgb               48068 non-null   float64
#  32  PTT               26439 non-null   float64
#  33  WBC               40929 non-null   float64
#  34  Fibrinogen        4164 non-null    float64
#  35  Platelets         35591 non-null   float64
#  36  Age               546122 non-null  float64
#  37  Gender            546122 non-null  float64
#  38  Unit1             274708 non-null  float64
#  39  Unit2             274708 non-null  float64
#  40  HospAdmTime       546122 non-null  float64
#  41  ICULOS            546122 non-null  float64
#  42  SepsisLabel       546122 non-null  float64
#  43  Patient_ID        546122 non-null  float64
# dtypes: float64(42), int64(2)
# memory usage: 183.3 MB

# %%
df['SepsisLabel'].value_counts()
# Out:
# SepsisLabel
# 0.0    534272
# 1.0     11850
# Name: count, dtype: int64

# %%
df['Patient_ID'].nunique()
# Out:
# 14057

# %%
df.groupby('Patient_ID')['Hour'].max().describe()
# Out:
# count    14057.000000
# mean        37.850537
# std         22.234872
# min          7.000000
# 25%         24.000000
# 50%         38.000000
# 75%         46.000000
# max        335.000000
# Name: Hour, dtype: float64

# %%
missing_pct = (
    df.isnull().mean()*100
).sort_values(ascending=False)

missing_pct.head(20)
# Out:
# EtCO2               100.000000
# TroponinI            99.874021
# Bilirubin_direct     99.850217
# Fibrinogen           99.237534
# Bilirubin_total      98.769874
# Alkalinephos         98.544284
# AST                  98.502352
# Lactate              96.578976
# PTT                  95.158783
# SaO2                 95.114654
# Calcium              95.022001
# Phosphate            94.945095
# Platelets            93.482970
# Creatinine           93.369259
# WBC                  92.505534
# Magnesium            92.237829
# HCO3                 91.966096
# BUN                  91.860808
# Chloride             91.703700
# PaCO2                91.290973
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop(
    columns=[
        "EtCO2",
        "TroponinI",
        "Bilirubin_direct",
        "Fibrinogen"
    ]
)

# %%
df["SepsisLabel"].value_counts(normalize=True) * 100
# Out:
# SepsisLabel
# 0.0    97.830155
# 1.0     2.169845
# Name: proportion, dtype: float64

# %%
missing_pct = (
    df.isnull()
      .mean()
      .mul(100)
      .sort_values(ascending=False)
)

missing_pct
# Out:
# Bilirubin_total    98.769874
# Alkalinephos       98.544284
# AST                98.502352
# Lactate            96.578976
# PTT                95.158783
# SaO2               95.114654
# Calcium            95.022001
# Phosphate          94.945095
# Platelets          93.482970
# Creatinine         93.369259
# WBC                92.505534
# Magnesium          92.237829
# HCO3               91.966096
# BUN                91.860808
# Chloride           91.703700
# PaCO2              91.290973
# Hgb                91.198320
# BaseExcess         89.658374
# Potassium          89.194925
# pH                 88.613371
# Hct                88.229941
# Glucose            87.858413
# FiO2               85.978433
# Temp               66.214388
# Unit1              49.698511
# Unit2              49.698511
# DBP                47.874197
# SBP                15.235213
# O2Sat              12.049300
# MAP                10.180124
# Resp                9.786806
# HR                  7.713098
# HospAdmTime         0.000183
# ICULOS              0.000183
# Gender              0.000183
# Age                 0.000183
# SepsisLabel         0.000183
# Patient_ID          0.000183
# Hour                0.000000
# Unnamed: 0          0.000000
# dtype: float64

# %%
df.groupby("Patient_ID")["SepsisLabel"].max().value_counts()
# Out:
# SepsisLabel
# 0.0    12818
# 1.0     1239
# Name: count, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['Unnamed: 0',
#  'Hour',
#  'HR',
#  'O2Sat',
#  'Temp',
#  'SBP',
#  'MAP',
#  'DBP',
#  'Resp',
#  'BaseExcess',
#  'HCO3',
#  'FiO2',
#  'pH',
#  'PaCO2',
#  'SaO2',
#  'AST',
#  'BUN',
#  'Alkalinephos',
#  'Calcium',
#  'Chloride',
#  'Creatinine',
#  'Glucose',
#  'Lactate',
#  'Magnesium',
#  'Phosphate',
#  'Potassium',
#  'Bilirubin_total',
#  'Hct',
#  'Hgb',
#  'PTT',
#  'WBC',
#  'Platelets',
#  'Age',
#  'Gender',
#  'Unit1',
#  'Unit2',
#  'HospAdmTime',
#  'ICULOS',
#  'SepsisLabel',
#  'Patient_ID']

# %%
df["Patient_ID"].nunique()
# Out:
# 14057

# %%
df.groupby("Patient_ID").size().describe()
# Out:
# count    14057.000000
# mean        38.850537
# std         22.234872
# min          8.000000
# 25%         25.000000
# 50%         39.000000
# 75%         47.000000
# max        336.000000
# dtype: float64

# %%
important_features = [
    "HR",
    "O2Sat",
    "Temp",
    "SBP",
    "MAP",
    "DBP",
    "Resp",
    "Creatinine",
    "Glucose",
    "Lactate",
    "WBC",
    "Platelets",
    "Age",
    "Gender",
    "HospAdmTime",
    "ICULOS",
    "SepsisLabel"
]

df[important_features].describe()
# Out:
#                   HR          O2Sat           Temp            SBP  \
# count  504000.000000  480319.000000  184511.000000  462920.000000
# mean       84.936506      97.258570      37.028197     121.097229
# std        16.933876       2.935284       0.783216      21.506672
# min        20.000000      20.000000      21.000000      22.000000
# 25%        73.000000      96.000000      36.560000     105.000000
# 50%        84.000000      98.000000      37.060000     119.000000
# 75%        96.000000      99.500000      37.560000     135.000000
# max       223.000000     100.000000      42.220000     274.000000
#
#                  MAP            DBP           Resp    Creatinine  \
# count  490527.000000  284671.000000  492675.000000  36212.000000
# mean       78.865428      60.102131      18.749110      1.395276
# std        15.057816      12.611608       5.379793      1.533622
# min        20.000000      20.000000       1.000000      0.100000
# 25%        68.330000      51.500000      15.000000      0.700000
# 50%        77.000000      59.000000      18.000000      0.900000
# 75%        87.670000      67.000000      22.000000      1.400000
# max       300.000000     298.000000      69.000000     46.600000
#
#             Glucose       Lactate           WBC     Platelets            Age  \
# count  66308.000000  18683.000000  40929.000000  35591.000000  546122.000000
# mean     133.759687      2.536370     11.877517    198.769724      63.008405
# std       51.472553      2.500318      7.862800    108.848196      16.150164
# min       10.000000      0.300000      0.100000      5.000000      18.110000
# 25%      104.000000      1.200000      8.000000    126.000000      52.670000
# 50%      124.000000      1.800000     10.800000    181.000000      65.270000
# 75%      150.000000      2.800000     14.200000    246.000000      76.020000
# max      988.000000     31.000000    422.900000   1783.000000      89.000000
#
#               Gender    HospAdmTime         ICULOS    SepsisLabel
# count  546122.000000  546122.000000  546122.000000  546122.000000
# mean        0.577182     -52.003997      27.159966       0.021698
# std         0.494007     148.651563      28.070839       0.145697
# min         0.000000   -3710.660000       1.000000       0.000000
# 25%         0.000000     -38.010000      11.000000       0.000000
# 50%         1.000000      -2.590000      21.000000       0.000000
# 75%         1.000000      -0.020000      35.000000       0.000000
# max         1.000000      23.990000     336.000000       1.000000
